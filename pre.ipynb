# %% [markdown]
# # 학회 준비 1

# %% [markdown]
# ---

# %% [markdown]
# > ### ***`프로젝트`***
# - 1)
#   - 어떤 데이터 셋이건 상관 없을 것 같은데 일단, 가장 간단한 데이터 셋인 붓꽃 데이터 셋을 활용한 간단한 머신러닝 파이프라인 구축 예제 실현해보기
#     - 이미 기존에 누군가 구현해놓은 파이프라인 예제를 답습하는 수준이긴 하지만, 머신러닝 파이프라인이라는 개념을 알아보는 차원에선 좋을 것 같음
#     - 기존의 머신러닝 -> 새로운 훈련 데이터 사용시마다 피쳐 엔지니어링, 모델 훈련, 분석 등의 과정이 수작업으로 재설정 되어야 함.
#     - 이는 많은 비용과 오류 발생
#     - 위의 일련의 과정을 자동화 된 머신러닝 파이프 라인을 통해 기존 모델의 유지보수에 드는 비용을 감축 가능. 이로써 새로운 모델 개발이 더 많은 시간을 투자할 수 있게 된다.
# - 2)
#   - 통계데이터 인공지능 활용대회 (자연어 기반 인공지능 산업분류 자동화)
#     - 팀으로 참여시 3인까지 가능
#     - 참가신청 : 3.7 ~ 3.21
#     - 개발 및 제출 : 3.14 ~ 4.13
#     - 심사 : 4.14 ~ 4.29
#     - 발표 / 시상 : 5.2 / 5.4
# - 3)
#   - 강서구 빅데이터 활용 공모전 (개방된 공공데이터를 활용하여 주민의 생활불편 해결 성공사례 및 공공 이익, 발전에 기여할 수 있는 자유주제)
#     - 팀으로 참여시 4인까지 가능
#     - 공공 데이터 포털에 공유돼 있는 강서구 관련 csv파일들 활용하여 주민 생활수준 향상 아이디어 공모전 같음.
#     - 참가신청 : 2.24 ~ 3.25
#     - 1차 서류 평가 : 3.28 ~ 3.30
#     - 2차 부서 평가 / 개별 통보 : 22. 4월 초
#     - 3차 최종 심사 : 22. 4월 중순
#     - 최종 발표 : 22. 4월 중순

# %% [markdown]
# ---

# %% [markdown]
# > ### ***`스터디`***
# - 파이썬 머신러닝 완벽 가이드
#   - 이미 학습하신 분이 있을 수 있을 것 같은데 일단 모두 시작하는 단계라고 생각하고 말씀드림.
#   - 해당 서적은 위에서 언급드린 세가지 프로젝트와 동떨어진 개념이 아니라서 복합적으로 병행할 수 있는 공부로서 스터디하면 좋을 것 같음.
#   - 총 대단원 9개로 분류, 첫 단원은 파이썬 사용법 같은 부분이라 skip 혹은 알아서 빠르게 복습할 수 있을 것 같고 본격적인 내용은 8개 단원.
#   - 궁극적인 팀 목적을 어디에 두느냐에 따라 스터디 방향도 달라질 수 있을 것 같음
#     - 유의미한 결과를 내는 프로젝트가 목적이라면 해당 스터디도 프로젝트에 도움이 될 수 있는 부분부터 발췌하여 보는 발췌독 식으로 할 수 있을 것 같음
#     - 또는 프로젝트에 치중하기보단 해당 서적을 통해 전체적인 개념 정립이 우선이라면 앞에서부터 차근차근 함께 리뷰하는 방향 + 부수적으로 프로젝트 진행
#     - 어쨌든 대략적인 틀
#       - 모두가 한 주 동안 동일한 부분과 분량을 공부
#       - 이때, 해당 부분의 책임자 있고, 이 사람이 해당 부분 관련한 과제 선정하면 될 것 같음(학회 활동 규칙에 매주 각자 과제 선정 후 제출하라는 게 있어서)(즉, 매주 해당 공부 분량의 담당자가 있고 미리 그 담당자는 미리 예습하여 과제 선정 후 예고..?, 아니면 과제 자체를 복습 개념으로 해도 될 것 같고..)
#       - 격주마다 세미나 있는 것도 아마 이 담당자가 발표자료 만들고 발표하면 될 것 같음(팀장 부담 줄일 수 있음)
#       - 세부적인 사항은 수정 가능
